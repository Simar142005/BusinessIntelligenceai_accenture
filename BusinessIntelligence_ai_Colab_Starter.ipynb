# %% [markdown]
# # BusinessIntelligence.ai — Colab Starter
# Run these cells after uploading and extracting the prototype ZIP.

# %%
import os
os.chdir('/content/BusinessIntelligence_ai_Round2_Prototype_Optimized')
print(os.getcwd())
print(os.listdir())

# %%
# !pip install -q -r requirements.txt

# %%
# !pkill -f streamlit || true
# !streamlit run app.py --server.port 8501 > /content/streamlit.log 2>&1 &
print('Streamlit started on port 8501')

# %% [markdown]
# ### Create a temporary public URL
# Install `cloudflared` in the next cell, then run the tunnel cell while the notebook is active.

# %%
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb

# %%
# !cloudflared tunnel --url http://localhost:8501
